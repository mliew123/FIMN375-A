# %% [markdown]
# # 1. Pricing the Callable Bond

# %%
#run this everytime an edit is made in utils.py so that we can use the helper functions in this Python Notebook
import importlib
import utils
importlib.reload(utils)
# Out:
# <module 'utils' from '/Users/matthewliew/FINM 375-a/matthew-work/hw-1/utils.py'>

# %%
import pandas as pd
import numpy as np

callable_bonds_info = pd.read_excel("callable_bonds_2025-02-13.xlsx", sheet_name="info")
callable_bonds_quotes = pd.read_excel("callable_bonds_2025-02-13.xlsx", sheet_name="quotes")

# %%
callable_bonds_info
# Out:
#                            info  FHLMC 0.97 01/28/28 FHLMC 1 1/4 01/29/30  \
# 0                         CUSIP            3134GW5F9            3134GWGK6
# 1                        Issuer          FREDDIE MAC          FREDDIE MAC
# 2                 Maturity Type             CALLABLE             CALLABLE
# 3               Issuer Industry          GOVT AGENCY          GOVT AGENCY
# 4                 Amount Issued             30000000             25000000
# 5                      Cpn Rate               0.0097               0.0125
# 6                      Cpn Freq                    2                    2
# 7                   Date Quoted  2025-02-13 00:00:00  2025-02-13 00:00:00
# 8                   Date Issued  2020-10-28 00:00:00  2020-07-29 00:00:00
# 9                  Date Matures  2028-01-28 00:00:00  2030-01-29 00:00:00
# 10  Date of First Possible Call  2021-01-28 00:00:00  2021-01-29 00:00:00
# 11               Date Next Call  2025-04-28 00:00:00  2025-04-29 00:00:00
# 12                       Strike                  100                  100
#
#     FHLMC 4.41 01/28/30
# 0             3134HA4V2
# 1           FREDDIE MAC
# 2              CALLABLE
# 3           GOVT AGENCY
# 4              10000000
# 5                0.0441
# 6                     2
# 7   2025-02-13 00:00:00
# 8   2025-01-28 00:00:00
# 9   2030-01-28 00:00:00
# 10  2028-01-28 00:00:00
# 11  2028-01-28 00:00:00
# 12                  100

# %%
callable_bonds_quotes
# Out:
#                  quotes  FHLMC 0.97 01/28/28 FHLMC 1 1/4 01/29/30  \
# 0           Date Quoted  2025-02-13 00:00:00  2025-02-13 00:00:00
# 1                   TTM             2.954141             4.958248
# 2           Clean Price               90.144              85.1095
# 3           Dirty Price            90.187111            85.161583
# 4      Accrued Interest             0.043111             0.052083
# 5              YTM Call            54.240686            85.395782
# 6          YTM Maturity             4.572927             4.646847
# 7              Duration             2.917203             4.806058
# 8     Modified Duration             2.851993             4.696929
# 9             Convexity             0.095944             0.248027
# 10  Treasury YLD Spread              25.1356              26.0091
# 11           OAS Spread            25.829994            25.969759
# 12          Implied Vol            19.598991            21.093378
#
#     FHLMC 4.41 01/28/30
# 0   2025-02-13 00:00:00
# 1               4.95551
# 2                99.893
# 3               100.089
# 4                 0.196
# 5              4.448321
# 6              4.433845
# 7              4.496738
# 8              4.399211
# 9              0.227173
# 10               4.7089
# 11           -26.768085
# 12            23.879829
